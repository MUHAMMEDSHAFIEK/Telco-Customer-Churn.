# %% [markdown]
# # **problem statement**
#
#
# **The data represents customer information for a telecommunications company, potentially for a churn analysis problem. The goal is likely to predict whether a customer will churn (leave the service) based on various attributes.**

# %% [markdown]
# # **Data Description**
#
#
# **This dataset appears to be related to customer churn analysis for a telecommunications company. Each row represents a customer, and the columns provide demographic, service, and billing details. Here's a breakdown of the fields:**

# %% [markdown]
# # **import libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # **Basic undarstand data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# # **5. Visualizations**
# **Correlation Heatmap**: Showcased the relationship between features and the target variable.
#
#
# **Class Distribution**: Count plots before and after oversampling displayed class balancing.
#
#
# **Feature Distributions**: Histograms and boxplots visualized feature distributions and identified outliers.

# %% [markdown]
# ## hisplot

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'SeniorCitizen'}>,
#         <Axes: title={'center': 'tenure'}>],
#        [<Axes: title={'center': 'MonthlyCharges'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## countplot

# %%
sns.countplot(y="Churn",data=df)
# Out:
# <Axes: xlabel='count', ylabel='Churn'>

# %% [markdown]
# ## boxplot

# %%
plt.figure(figsize=(10,10))
sns.boxplot(df,orient='h',palette='Set1')
plt.show()

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # **DATA CLEANING and PREPARATION**

# %%
df["PaymentMethod"].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df["Contract"].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Mapping ordinal values to numbers
ordinal_mapping = {'Month-to-month':1, 'One year':2, 'Two year':3}
df["Contract"] = df["Contract"].map(ordinal_mapping)

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
le = LabelEncoder()

# Fit the encoder to the 'loan_status' column and transform it
df['Churn'] = le.fit_transform(df['Churn'])
df['gender'] = le.fit_transform(df['gender'])
df['Partner'] = le.fit_transform(df['Partner'])
df['Dependents'] = le.fit_transform(df['Dependents'])
df['PhoneService'] = le.fit_transform(df['PhoneService'])
df['MultipleLines'] = le.fit_transform(df['MultipleLines'])
df['InternetService'] = le.fit_transform(df['InternetService'])
df['OnlineSecurity'] = le.fit_transform(df['OnlineSecurity'])
df['OnlineBackup'] = le.fit_transform(df['OnlineBackup'])
df['DeviceProtection'] = le.fit_transform(df['DeviceProtection'])
df['TechSupport'] = le.fit_transform(df['TechSupport'])
df['StreamingTV'] = le.fit_transform(df['StreamingTV'])
df['StreamingMovies'] = le.fit_transform(df['StreamingMovies'])
df['PaperlessBilling'] = le.fit_transform(df['PaperlessBilling'])
df['PaymentMethod'] = le.fit_transform(df['PaymentMethod'])
df["customerID"] = le.fit_transform(df["customerID"])
#df["TotalCharges"] = le.fit_transform(df["TotalCharges"])

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

df['TotalCharges'] = df['TotalCharges'].fillna(df['TotalCharges'].median())

# %%
df.drop("customerID",axis=1,inplace=True)

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %% [markdown]
# # **over_sampling**

# %%
sns.countplot(y="Churn",data=df)
# Out:
# <Axes: xlabel='count', ylabel='Churn'>

# %%
# install imblearn
from imblearn.over_sampling import RandomOverSampler, SMOTE # import with correct module name

# %%
#assuming 'df' is your DataFrame with 'Churn' as the target variable
x=df.drop('Churn',axis=1)
y=df['Churn']


#screatan oversampler object (choose either randomoversampler or SMOTE)
#Uncomment the one you want to use
#ros=randomOversampler() for random Oversampling
ros=SMOTE()#for sythetic minority

#Apply the oversampler to the data
x_resampled,y_resampled=ros.fit_resample(x,y)

x_resampled=pd.DataFrame(x_resampled,columns=x.columns)
y_resampled=pd.Series(y_resampled,name='Churn')

df=pd.concat([x_resampled,y_resampled],axis=1)

# %%
sns.countplot(y="Churn", data=df)
# Out:
# <Axes: xlabel='count', ylabel='Churn'>

# %% [markdown]
# # **CORRELATION ANALYSIS**

# %%
corr_matrix=df.corr()
plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.show()

# %%
cor=df.corr()['Churn'].sort_values(ascending=False)
cor
# Out:
# Churn               1.000000
# MonthlyCharges      0.232404
# PaperlessBilling    0.111220
# PaymentMethod       0.056419
# SeniorCitizen       0.018936
# PhoneService       -0.012727
# MultipleLines      -0.014049
# InternetService    -0.083717
# StreamingMovies    -0.101658
# StreamingTV        -0.104847
# gender             -0.152368
# TotalCharges       -0.244691
# DeviceProtection   -0.279095
# OnlineBackup       -0.289861
# Dependents         -0.309622
# Partner            -0.313789
# TechSupport        -0.403774
# OnlineSecurity     -0.407945
# tenure             -0.424967
# Contract           -0.525437
# Name: Churn, dtype: float64

# %%
# Drop low-correlation columns from the DataFrame
df.drop(["SeniorCitizen", "MultipleLines", "PhoneService", "InternetService", "StreamingTV", "StreamingMovies","gender","PaymentMethod","PaperlessBilling"], axis=1,inplace=True)

# %%
df
# Out:
#        Partner  Dependents  tenure  OnlineSecurity  OnlineBackup  \
# 0            1           0       1               0             2
# 1            0           0      34               2             0
# 2            0           0       2               2             2
# 3            0           0      45               2             0
# 4            0           0       2               0             0
# ...        ...         ...     ...             ...           ...
# 10343        0           0       8               0             0
# 10344        0           0       1               0             0
# 10345        0           0       1               0             0
# 10346        0           0      65               0             2
# 10347        0           0       2               0             0
#
#        DeviceProtection  TechSupport  Contract  MonthlyCharges  TotalCharges  \
# 0                     0            0         1       29.850000     29.850000
# ...

# %% [markdown]
# # **OUTLIER HANDLING**

# %%
plt.figure(figsize=(10,10))
sns.boxplot(df,orient='h',palette='Set1')
plt.show()

# %%
import numpy as np

# %%
Q1=np.quantile(df,0.25)
Q2=np.quantile(df,0.50)
Q3=np.quantile(df,0.75)
Q1,Q2,Q3
IQR=Q3-Q1
IQR
# Out:
# 5.0

# %%
def remove_outliers_iqr(df, column):
    # Calculate Q1 (25th percentile) and Q3 (75th percentile) for the column
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)

    # Calculate the Interquartile Range (IQR)
    IQR = Q3 - Q1

    # Define the lower and upper bounds for detecting outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter out the outliers from the DataFrame
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_filtered


df_no_outliers = remove_outliers_iqr(df,'TotalCharges')

# %% [markdown]
# # **SKEWNESS HANDLING**

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Partner'}>,
#         <Axes: title={'center': 'Dependents'}>,
#         <Axes: title={'center': 'tenure'}>],
#        [<Axes: title={'center': 'OnlineSecurity'}>,
#         <Axes: title={'center': 'OnlineBackup'}>,
#         <Axes: title={'center': 'DeviceProtection'}>],
#        [<Axes: title={'center': 'TechSupport'}>,
#         <Axes: title={'center': 'Contract'}>,
#         <Axes: title={'center': 'MonthlyCharges'}>],
#        [<Axes: title={'center': 'TotalCharges'}>,
#         <Axes: title={'center': 'Churn'}>, <Axes: >]], dtype=object)

# %%
#To handle skewness
import numpy as np

# Correct column names and using them in a list
columns_to_transform = ['TotalCharges', 'MonthlyCharges', 'tenure']

# Apply log transformation to the selected columns
log_data = np.log(df[columns_to_transform] + 1)  # Adding 1 to avoid log(0)


# Assuming log_data is a DataFrame with multiple features
num_features = log_data.shape[1]  # Number of features
plt.figure(figsize=(50, 15))  # Adjust the figure size as needed

for i, column in enumerate(log_data.columns, 1):
    plt.subplot(1, num_features, i)  # Adjust layout for each feature
    sns.histplot(log_data[column], bins=30, kde=True)
    plt.title(f"Log-Transformed {column}")

plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (10348, 11)

# %% [markdown]
# # **Model Training and Evaluation**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
df.columns
# Out:
# Index(['Partner', 'Dependents', 'tenure', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'Contract', 'MonthlyCharges',
#        'TotalCharges', 'Churn'],
#       dtype='object')

# %%
independet_feature = ['Partner', 'Dependents', 'tenure', 'OnlineSecurity', 'OnlineBackup',
       'DeviceProtection', 'TechSupport', 'Contract', 'MonthlyCharges',
       'TotalCharges']
dependet_feature = ['Churn']
x = df[independet_feature]
y = df[dependet_feature]

# %% [markdown]
# # **StandardScaler**

# %%
from sklearn.preprocessing import StandardScaler # Import StandardScaler
# Create and fit the scaler
scaler = StandardScaler()
scaler.fit(x)

# Transform the data
X_scaled = scaler.transform(x)
# X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Split data into training and testing sets

# %%
# Assuming you have your features in 'X' and target variable in 'y'

# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # **GradientBoostingClassifier**

# %%
from sklearn.ensemble import  GradientBoostingClassifier

# %%
# Create a GradientBoostingClassifiert Classifier object
model_1 = GradientBoostingClassifier()  # You can adjust hyperparameters

# Train the model
model_1.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model_1.predict(x_test)

print("accuracy_score",accuracy_score(y_test, y_pred))

print("Precision:", precision_score(y_test, y_pred, average="weighted"))

print('Recall:', recall_score(y_test, y_pred, average="weighted"))

print('F1 Score:', f1_score(y_test, y_pred, average="weighted"))

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# accuracy_score 0.8309178743961353
# Precision: 0.8329300010797908
# Recall: 0.8309178743961353
# F1 Score: 0.8305455447874415
# array([[804, 217],
#        [133, 916]])

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
conf_matrix=np.array([[805, 216],
                      [149, 900]])
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # **xgboost**

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# Create an XGBoost Classifier object
model_2 = xgb.XGBClassifier()  # You can adjust hyperparameters

# Train the model
model_2.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model_2.predict(x_test)


cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[835, 186],
#        [149, 900]])

# %%
from sklearn.metrics import precision_score,recall_score, f1_score, accuracy_score,confusion_matrix
print("accuracy_score",accuracy_score(y_test, y_pred))

print("Precision:", precision_score(y_test, y_pred, average="weighted"))

print('Recall:', recall_score(y_test, y_pred, average="weighted"))

print('F1 Score:', f1_score(y_test, y_pred, average="weighted"))
# Out:
# accuracy_score 0.8381642512077294
# Precision: 0.8385190214000787
# Recall: 0.8381642512077294
# F1 Score: 0.8380733274688693

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
conf_matrix=np.array([[838, 183],
       [162, 887]])
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # **RandomForestClassifier**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Create an RandomForestClassifier Classifier object
model_3 = RandomForestClassifier()  # You can adjust hyperparameters

# Train the model
model_3.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model_3.predict(x_test)

print("accuracy_score",accuracy_score(y_test, y_pred))

print("Precision:", precision_score(y_test, y_pred, average="weighted"))

print('Recall:', recall_score(y_test, y_pred, average="weighted"))

print('F1 Score:', f1_score(y_test, y_pred, average="weighted"))

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# accuracy_score 0.8396135265700483
# Precision: 0.8396505868374005
# Recall: 0.8396135265700483
# F1 Score: 0.8396195160287363
# array([[859, 162],
#        [170, 879]])

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
conf_matrix=np.array([[860, 161],
       [185, 864]])
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # **LogisticRegression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Create an LogisticRegression Classifier object
model_4 =LogisticRegression()  # You can adjust hyperparameters

# Train the model
model_4.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model_4.predict(x_test)

print("accuracy_score",accuracy_score(y_test, y_pred))

print("Precision:", precision_score(y_test, y_pred, average="weighted"))

print('Recall:', recall_score(y_test, y_pred, average="weighted"))

print('F1 Score:', f1_score(y_test, y_pred, average="weighted"))

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# accuracy_score 0.8038647342995169
# Precision: 0.8051596138664235
# Recall: 0.8038647342995169
# F1 Score: 0.803534393493172
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[782, 239],
#        [167, 882]])

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
conf_matrix=np.array([[782, 239],
       [177, 872]])
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # **KNeighborsClassifier**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Create an KNeighborsClassifier Classifier object
model_5 =KNeighborsClassifier()  # You can adjust hyperparameters

# Train the model
model_5.fit(x_train, y_train)

# Make predictions on the test set
y_pred = model_5.predict(x_test)

print("accuracy_score",accuracy_score(y_test, y_pred))

print("Precision:", precision_score(y_test, y_pred, average="weighted"))

print('Recall:', recall_score(y_test, y_pred, average="weighted"))

print('F1 Score:', f1_score(y_test, y_pred, average="weighted"))

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# accuracy_score 0.8082125603864734
# Precision: 0.8083383229223016
# Recall: 0.8082125603864734
# F1 Score: 0.8082209305384014
# array([[831, 190],
#        [207, 842]])

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
conf_matrix=np.array([[832, 189],
       [192, 857]])
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# # **summarizing the algorithms**
#
#
#
#
# This script compares the performance of five popular machine learning algorithms for classification tasks. Gradient Boosting Classifier and XGBoost Classifier are ensemble methods that build strong models by combining weaker models iteratively, with XGBoost being faster and highly optimized. The Random Forest Classifier creates multiple decision trees and aggregates their predictions for better accuracy and reduced overfitting. Logistic Regression is a simple and interpretable linear model suitable for baseline comparisons. Lastly, the K-Nearest Neighbors (KNN) Classifier predicts based on the majority class of the nearest neighbors, making it sensitive to the choice of hyperparameters like the number of neighbors. Each algorithm's performance is evaluated using accuracy and confusion matrices.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The XGBoost Classifier has an accuracy of 83.3% and is fast and efficient for large datasets. It improves performance by combining multiple weak models. Random Forest, with an accuracy of 83.2%, builds several decision trees and combines their predictions, which helps reduce overfitting. Gradient Boosting has an accuracy of 82.3% and builds strong models by adding trees that correct errors from the previous ones. K-Nearest Neighbors (KNN), with 81.5% accuracy, classifies data points based on the majority label of their closest neighbors, but it can be slow and sensitive to parameters. Logistic Regression, with an accuracy of 79.8%, is a simple linear model often used as a starting point for classification tasks.
#
# This version provides the key details in a more straightforward way. Let me know if you need any further changes!
